# %%
# loading the data
import pandas as pd
df = pd.read_csv('image-descriptions-DFE5.csv',header=0)
df
# Out:
#           UnitId   TrustedJudgement Response  ConfidenceScore   \
# 0       110494178                 4       No            0.5243
# 1       110494179                 3       No            1.0000
# 2       110494180               139      Yes            1.0000
# 3       110494181                 3       No            1.0000
# 4       110494182                45       No            0.9316
# ...           ...               ...      ...               ...
# 226226  111036627               154      Yes            0.9596
# 226227  111036628                73       No            0.8028
# 226228  111036629                40       No            0.9192
# 226229  111036630               157       No            1.0000
# 226230  111036631               160      Yes            0.9612
#
#                                                     Image             Phrase
# 0       http://clic.cimec.unitn.it/~elia.bruni/crowdfl...         disneyland
# ...

# %%
#converted Response to numerical variable
pd.get_dummies(df.Response)
# Out:
#         No  Yes
# 0        1    0
# 1        1    0
# 2        0    1
# 3        1    0
# 4        1    0
# ...     ..  ...
# 226226   0    1
# 226227   1    0
# 226228   1    0
# 226229   1    0
# 226230   0    1
#
# [226231 rows x 2 columns]

# %%
#converted Image to numerical variable
pd.get_dummies(df.Image)
# Out:
#         http://clic.cimec.unitn.it/~elia.bruni/crowdflower/mirflickr/100k-images/im100000.jpg  \
# 0                                                       0
# 1                                                       0
# 2                                                       0
# 3                                                       0
# 4                                                       0
# ...                                                   ...
# 226226                                                  0
# 226227                                                  0
# 226228                                                  0
# 226229                                                  0
# 226230                                                  0
#
#         http://clic.cimec.unitn.it/~elia.bruni/crowdflower/mirflickr/100k-images/im100052.jpg  \
# 0                                                       0
# 1                                                       0
# ...
