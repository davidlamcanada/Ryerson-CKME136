# %%
model1 = pd.read_csv("image-descriptions-DFE4DecisionTree.csv", header=None)

# %%
model1
# Out:
#                 0      1          2    3                 4    5       6    7  \
# 0       110494178  False  finalized    4   11/25/2011 5:26   No  0.5243  NaN
# 1       110494179  False  finalized    3  11/15/2011 20:33   No  1.0000  NaN
# 2       110494180   True     golden  139  11/24/2011 17:09  Yes  1.0000  Yes
# 3       110494181  False  finalized    3  11/19/2011 12:57   No  1.0000  NaN
# 4       110494182   True     golden   45   11/23/2011 2:27   No  0.9316   No
# ...           ...    ...        ...  ...               ...  ...     ...  ...
# 226226  111036627   True     golden  154  11/24/2011 18:28  Yes  0.9596  Yes
# 226227  111036628   True     golden   73  11/22/2011 18:27   No  0.8028   No
# 226228  111036629   True     golden   40  11/22/2011 18:52   No  0.9192   No
# 226229  111036630   True     golden  157   11/24/2011 7:29   No  1.0000   No
# 226230  111036631   True     golden  160  11/24/2011 16:52  Yes  0.9612  Yes
#
# ...

# %%
feature_cols = ['Question', 'Unit_State', 'Trusted_Judgement', 'Last_Judgement','Response','Confidence_Score','Best_Pair','Image','Phrases']
X = model1[feature_cols] 
y = model1.Unit_Id
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-8625ccbe7119> in <module>
#       1 feature_cols = ['Question', 'Unit_State', 'Trusted_Judgement', 'Last_Judgement','Response','Confidence_Score','Best_Pair','Image','Phrases']
# ----> 2 X = model1[feature_cols]
#       3 y = model1.Unit_Id
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# ...
